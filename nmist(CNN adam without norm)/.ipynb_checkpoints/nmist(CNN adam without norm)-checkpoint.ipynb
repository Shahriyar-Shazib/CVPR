# %% [markdown]
# <h1>nmlist with CNN (without normalized,adam)</h1>

# %%
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers
from tensorflow.keras.datasets import mnist

import os
import random
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# # Load Data Set nmist and printing dimentions test and train dataset

# %%
(x_train, y_train), (x_test, y_test) = mnist.load_data()
print(f"Shape of x_train: {x_train.shape}")
print(f"Shape of y_train: {y_train.shape}")
print()
print(f"Shape of x_test: {x_test.shape}")
print(f"Shape of y_test: {y_test.shape}")
# Out:
# Shape of x_train: (60000, 28, 28)
# Shape of y_train: (60000,)
#
# Shape of x_test: (10000, 28, 28)
# Shape of y_test: (10000,)

# %% [markdown]
# # printing a train value with lavels  from data set

# %%
digit = 9 # Change to choose new digit
a = x_train[digit]
plt.imshow(a, cmap='gray_r')
print(f"Image (#{digit}): Which is digit '{y_train[digit]}'")
# Out:
# Image (#9): Which is digit '4'

# %% [markdown]
# # normalize tehe picture and reshape the dimention

# %%
X_train = x_train.reshape(-1, 28*28*1).astype("float32") / 255.0
X_test = x_test.reshape(-1, 28*28*1).astype("float32") / 255.0
print(f"Shape of x_train: {X_train.shape}")
print(f"Shape of y_train: {y_train.shape}")
print()
print(f"Shape of x_test: {X_test.shape}")
print(f"Shape of y_test: {y_test.shape}")
# Out:
# Shape of x_train: (60000, 784)
# Shape of y_train: (60000,)
#
# Shape of x_test: (10000, 784)
# Shape of y_test: (10000,)

# %%
ROWS = 3
COLS = 20
i = 0

plt.figure(figsize=(20,3))
for r in range(ROWS):
    for c in range(COLS):
        plt.subplot(ROWS, COLS, i+1)
        plt.imshow(x_train[i], cmap=plt.cm.gray_r)
        
        plt.xticks([])
        plt.yticks([])
        plt.xlabel(y_train[i])
        i += 1
plt.tight_layout()
plt.show()

# %% [markdown]
# # reshaping without normalized

# %%
X_train = x_train.reshape(-1, 28*28*1)
X_test = x_test.reshape(-1, 28*28*1)

# %% [markdown]
# # creating model for train data set

# %%
model1 = keras.Sequential([
    ## input layer
    keras.Input(shape=(28,28,1)),
    
    ## hidden layers
    
    layers.Conv2D(filters=128, kernel_size=(5,5), activation='relu'), # input->(32,32) output->(28,28) hwew we use 128 filters and kernel size 5,5
    layers.MaxPooling2D(pool_size=(2,2)),
    layers.Conv2D(filters=128, kernel_size=(3,3), activation='relu'),
    layers.MaxPooling2D(pool_size=(2,2)),
    layers.Conv2D(filters=256, kernel_size=(3,3), activation='relu'),
    layers.MaxPooling2D(pool_size=(2,2)),
    
    
    layers.Flatten(),
    
    layers.Dense(128, activation='relu'),
    
    ## output layer
    layers.Dense(10, activation='softmax')
])
model1.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d (Conv2D)              (None, 24, 24, 128)       3328
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 12, 12, 128)       0
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 10, 10, 128)       147584
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 5, 5, 128)         0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 3, 3, 256)         295168
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 1, 1, 256)         0
# _________________________________________________________________
# flatten (Flatten)            (None, 256)               0
# _________________________________________________________________
# dense (Dense)                (None, 128)               32896
# _________________________________________________________________
# dense_1 (Dense)              (None, 10)                1290
# =================================================================
# Total params: 480,266
# Trainable params: 480,266
# Non-trainable params: 0
# _________________________________________________________________

# %%
model1.compile(
    optimizer='adam', 
    loss='sparse_categorical_crossentropy', 
    metrics=['accuracy']
)

# %% [markdown]
# # reshape the image dimention to fit in our model

# %%
x1_train=x_train.reshape(-1,28,28,1)
x1_test=x_test.reshape(-1,28,28,1)
print(x_train[0].shape)
# Out:
# (28, 28)

# %% [markdown]
# # use model1.fit to train the machine

# %%
 h = model1.fit(x=x1_train, y=y_train, epochs=5,validation_split=0.2, batch_size=32 )
# Out:
# Epoch 1/5
# 1500/1500 [==============================] - 206s 137ms/step - loss: 1.1793 - accuracy: 0.8625 - val_loss: 0.0994 - val_accuracy: 0.9714
# Epoch 2/5
# 1500/1500 [==============================] - 190s 127ms/step - loss: 0.0798 - accuracy: 0.9753 - val_loss: 0.0842 - val_accuracy: 0.9777
# Epoch 3/5
# 1500/1500 [==============================] - 191s 128ms/step - loss: 0.0667 - accuracy: 0.9796 - val_loss: 0.0862 - val_accuracy: 0.9744
# Epoch 4/5
# 1500/1500 [==============================] - 217s 145ms/step - loss: 0.0587 - accuracy: 0.9828 - val_loss: 0.0616 - val_accuracy: 0.9837
# Epoch 5/5
# 1500/1500 [==============================] - 215s 143ms/step - loss: 0.0418 - accuracy: 0.9878 - val_loss: 0.0671 - val_accuracy: 0.9839

# %% [markdown]
# # plot the result of training and show the training accuracy and validation accuracy also plot the loss

# %%
plt.figure(figsize=(15,5))
plt.subplot(1,2,1)
plt.plot(h.history['accuracy'], 'o-', label='train accuracy')
plt.plot(h.history['val_accuracy'], 'o-', label = 'validation accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.grid(True)
plt.legend(loc='lower right')

plt.subplot(1,2,2)
plt.plot(h.history['loss'], 'o-', label='train loss')
plt.plot(h.history['val_loss'], 'o-', label='validation loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.grid(True)
plt.legend(loc='upper right')

plt.show()

# %% [markdown]
# # test data in our trained machine

# %%
test_loss, test_acc = model1.evaluate(x1_test, y_test)
print('\nTest accuracy:', test_acc)
# Out:
# 313/313 [==============================] - 8s 24ms/step - loss: 0.0639 - accuracy: 0.9832
#
# Test accuracy: 0.9832000136375427

# %% [markdown]
# # predict results for our test data

# %%
predictions = model1.predict(x1_test)

# %%
ROWS = 5
COLS = 20

random_indices = random.sample(range(x_test.shape[0]), ROWS*COLS)
sample_images = x1_test[random_indices, :]
sample_labels = y_test[random_indices]
predictions = model1.predict(sample_images)

i = 0

plt.figure(figsize=(20,5))
for r in range(ROWS):
    for c in range(COLS):
        plt.subplot(ROWS, COLS, i+1)
        plt.imshow(sample_images[i].reshape(28,28), cmap=plt.cm.gray)
        plt.xticks([])
        plt.yticks([])
        prediction = np.argmax(predictions[i]) 
        confidence = predictions[i][prediction]
        if sample_labels[i] == prediction:
            plt.xlabel(f"{prediction} ({confidence: .2f})", color='b')
        else:
            plt.xlabel(f"{prediction} ({confidence: .2f})", color='r')
        plt.ylabel(sample_labels[i], color='g')
        i += 1
        
plt.tight_layout()
plt.show()

# %%
def test(i):
    img = x1_test[i]
    predictions = model1.predict([img.reshape(-1,28,28,1)])

    plt.figure()
    plt.imshow(img.reshape(28,28), cmap='gray_r')
    plt.xticks([])
    plt.yticks([])

    plt.ylabel(f"True Label: {y_test[i]}", color='g') # ground truth

    prediction = np.argmax(predictions) 
    confidence = predictions[0][prediction]

    if y_test[i] == prediction:
        plt.xlabel(f"prediction = {prediction} (Confidence Score = {confidence: .2f})", color='b')
    else:
        plt.xlabel(f"prediction = {prediction} (Confidence Score = {confidence: .2f})", color='r')
    plt.show()

# %%
test(100)
